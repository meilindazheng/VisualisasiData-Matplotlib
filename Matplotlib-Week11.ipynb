# %% [markdown]
# ![matplotlib.png](attachment:matplotlib.png)

# %% [markdown]
# ## [19] Animasi pada Matplotlib

# %% [markdown]
# ### [19.1] Import Module

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt

from matplotlib.animation import FuncAnimation
import matplotlib.animation as manimation; manimation.writers.list()
from IPython import display
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.2.2
# 1.18.5

# %% [markdown]
# ### [19.2] Review Figure
# - plt.xlim() menerima 2 parameter yang mengindikasikan titik mulai dan titik berakhir sumbu x pada figure
# - plt.ylim() menerima 2 parameter yang mengindikasikan titik mulai dan titik berakhir sumbu y pada figure

# %%
fig = plt.figure()
plt.xlim(0,4)
plt.ylim(-2,2)

print(plt.plot([]))

# %% [markdown]
# ### [19.3] Animasi pada Matplotlib

# %%
fig = plt.figure()
plt.xlim(0,4)
plt.ylim(-2,2)

line = plt.plot([])[0]

def animate(i):
    x = np.linspace(0,4,1000)
    y = np.sin(2 * np.pi *(x-0.01*i))
    line.set_data(x,y)
    return line,

anim = FuncAnimation(fig,animate,frames=200,interval=20)

video = anim.to_html5_video()
html = display.HTML(video)
display.display(html)

plt.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-cf4b24720481> in <module>
#      13 anim = FuncAnimation(fig,animate,frames=200,interval=20)
#      14
# ---> 15 video = anim.to_html5_video()
#      16 html = display.HTML(video)
#      17 display.display(html)
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in to_html5_video(self, embed_limit)
#    1326                 # We create a writer manually so that we can get the
#    1327                 # appropriate size for the tag
# -> 1328                 Writer = writers[rcParams['animation.writer']]
#    1329                 writer = Writer(codec='h264',
#    1330                                 bitrate=rcParams['animation.bitrate'],
#
# ~\anaconda3\lib\site-packages\matplotlib\animation.py in __getitem__(self, name)
#     162         if self.is_available(name):
# ...
