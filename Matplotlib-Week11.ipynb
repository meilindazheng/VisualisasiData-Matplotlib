# %% [markdown]
# ![matplotlib.png](attachment:matplotlib.png)

# %% [markdown]
# ## [19] Animasi pada Matplotlib

# %% [markdown]
# ### [19.1] Import Module

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt

from matplotlib.animation import FuncAnimation
from IPython import display
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.2.2
# 1.18.5

# %% [markdown]
# ### [19.2] Review Figure
# - plt.xlim() menerima 2 parameter yang mengindikasikan titik mulai dan

# %%
fig = plt.figure()
plt.xlim(0,4)
plt.ylim(-2,2)

print(plt.plot([]))
# Out:
# [<matplotlib.lines.Line2D object at 0x0000022042186730>]
